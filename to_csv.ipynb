# %%
import pandas

# %%
# raw_train_data = open("datasets/train.tsv","r",encoding="utf-8").read()
raw_test_data = open("datasets/train.tsv","r",encoding="utf-8").read()

# %%
i = 0
l = []
for line in raw_test_data.split("\n") : 
# for line in raw_train_data.split("\n") : 
    if str(line).strip() == '':
        continue
    l.append(line.split("\t"))

# %%
len(l)
# Out:
# 6157

# %%
final_data = pandas.DataFrame(l)

# %%
# final_data.to_csv("datasets/train.csv")
final_data.to_csv("datasets/test.csv")
